# %%
import pandas as pd
import numpy as np

# %%
# Load data
df = pd.read_csv("Airbnb_Open_Data.csv")
# Out:
# C:\Users\ELCOT\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#Clean Column Names (snake_case)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Know your data
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service_fee minimum_nights  \
# ...

# %%
pd.set_option('display.max_columns', 30)

# %%
df.shape
# Out:
# (102599, 26)

# %%
df.isnull().sum()
# Out:
# id                                     0
# name                                 250
# host_id                                0
# host_identity_verified               289
# host_name                            406
# neighbourhood_group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country_code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room_type                              0
# construction_year                    214
# price                                247
# service_fee                          273
# minimum_nights                       409
# number_of_reviews                    183
# last_review                        15893
# reviews_per_month                  15879
# review_rate_number                   326
# calculated_host_listings_count       319
# ...

# %%
# data types
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_identity_verified             object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country_code                       object
# instant_bookable                   object
# cancellation_policy                object
# room_type                          object
# construction_year                 float64
# price                              object
# service_fee                        object
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# review_rate_number                float64
# ...

# %%
# Remove Duplicates
df = df.drop_duplicates()

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
# Handle Missing Values Logically
# Identify missing data
missing_summary = df.isnull().sum().sort_values(ascending=False)
print("Missing values per column:\n", missing_summary)
# Out:
# Missing values per column:
#  license                           102056
# house_rules                        51842
# last_review                        15832
# reviews_per_month                  15818
# country                              532
# availability_365                     448
# host_name                            404
# minimum_nights                       400
# review_rate_number                   319
# calculated_host_listings_count       319
# host_identity_verified               289
# service_fee                          273
# name                                 250
# price                                247
# construction_year                    214
# number_of_reviews                    183
# country_code                         131
# instant_bookable                     105
# cancellation_policy                   76
# neighbourhood_group                   29
# neighbourhood                         16
# long                                   8
# ...

# %%
# Fill numeric columns with 0 or median, string columns with mode or 'Unknown' only if logical
fill_zero_cols = ['minimum_nights', 'number_of_reviews', 'review_rate_number', 'calculated_host_listings_count', 'availability_365']
for col in fill_zero_cols:
    df[col] = df[col].fillna(0).astype(int)

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_identity_verified             object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country_code                       object
# instant_bookable                   object
# cancellation_policy                object
# room_type                          object
# construction_year                 float64
# price                              object
# service_fee                        object
# minimum_nights                      int32
# number_of_reviews                   int32
# last_review                        object
# reviews_per_month                 float64
# review_rate_number                  int32
# ...

# %%
# Clean and Convert Price & Fees Columns
for money_col in ['price', 'service_fee']:
    df[money_col] = (
        df[money_col]
        .astype(str)
        .replace('[\$,]', '', regex=True)
        .replace('nan', 0)
        .astype(float)
    )

# %%
# Parse Dates & Handle Date Features
if 'last_review' in df.columns:
    df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
#Standardize Categorical Columns (lowercase, no spaces)
cat_cols = ['host_identity_verified', 'cancellation_policy', 'room_type', 'neighbourhood']
for col in cat_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.lower().str.replace(' ', '_')

# %%
#Fix Construction Year or Other Int Columns
if 'construction_year' in df.columns:
    df['construction_year'] = (
        df['construction_year']
        .fillna('2012')
        .astype(str)
        .str.extract(r'(\d{4})')
        .astype(int)
    )

# %%
#Drop Unnecessary Columns
drop_cols = ['house_rules', 'country', 'country_code', 'name', 'license', 'reviews_per_month']
for col in drop_cols:
    if col in df.columns:
        df.drop(columns=[col], inplace=True)

# %%
# Final Clean
df = df.dropna()  # Only if needed for downstream tasks

# %%
df.head()
# Out:
#         id      host_id host_identity_verified host_name neighbourhood_group  \
# 0  1001254  80014485718            unconfirmed  Madaline            Brooklyn
# 1  1002102  52335172823               verified     Jenna           Manhattan
# 3  1002755  85098326012            unconfirmed     Garry            Brooklyn
# 4  1003689  92037596077               verified    Lyndon           Manhattan
# 5  1004098  45498551794               verified  Michelle           Manhattan
#
#   neighbourhood       lat      long instant_bookable cancellation_policy  \
# 0    kensington  40.64749 -73.97237            False              strict
# 1       midtown  40.75362 -73.98377            False            moderate
# 3  clinton_hill  40.68514 -73.95976             True            moderate
# 4   east_harlem  40.79851 -73.94399            False            moderate
# 5   murray_hill  40.74767 -73.97500             True            flexible
#
# ...

# %%
#Save Cleaned Data
df.to_csv("airbnb_cleaned.csv", index=False)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85781 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              85781 non-null  int64
#  1   host_id                         85781 non-null  int64
#  2   host_identity_verified          85781 non-null  object
#  3   host_name                       85781 non-null  object
#  4   neighbourhood_group             85781 non-null  object
#  5   neighbourhood                   85781 non-null  object
#  6   lat                             85781 non-null  float64
#  7   long                            85781 non-null  float64
#  8   instant_bookable                85781 non-null  object
#  9   cancellation_policy             85781 non-null  object
#  10  room_type                       85781 non-null  object
#  11  construction_year               85781 non-null  int32
# ...
